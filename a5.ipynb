# %% [markdown]
# Visualização de Grafos com NetworkX

# %%
import networkx as nx
import matplotlib.pyplot as plt
from pygments.styles.dracula import background

g = nx.Graph()
g.add_node('A', tipo='letra', cor='azul')
g.add_node('B', tipo='letra')
g.add_node('3', tipo='numero')
g.add_node('4', tipo='numero')
g.add_edge('A', '3', peso=5)
g.add_edge('B', '3', peso=3)

# print(g)
# print(g.nodes.data())
# print(g.edges.data())
# print(g.has_edge('B', 'A'))


nx.draw(g, with_labels=True, node_size=800, node_color="#FFF200")
plt.savefig('grafo1.png')
plt.show()
